# %%
print("Olá sou o Robert")
# Out:
# Olá sou o Robert

# %%
b = [1, 2, 3]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

numeros = np.random.randn(50).cumsum()
print(numeros)

plt.plot(np.random.randn(50).cumsum())
plt.plot(np.cumsum([0, 1, 2, 3, 4, 5]))

plt.show()
# Out:
# [-1.12771336 -1.11644487 -1.56554732 -1.07625582 -0.68532228  0.11032689
#   0.93875011 -0.78356724 -0.39172695 -1.75895541 -1.94209927 -0.60734738
#  -2.58522625 -3.35061955 -4.02163318 -3.25004654 -2.86968024 -3.7717403
#  -1.81848397 -0.9053924  -1.11578414 -2.97625669 -3.34778009 -4.75139524
#  -5.36749521 -6.55400066 -6.04179771 -5.23847329 -4.78212283 -5.39428717
#  -6.0013574  -4.26848245 -5.38060671 -5.23118129 -4.52426148 -2.70370218
#  -3.46778409 -3.85777298 -3.27642022 -4.03136889 -4.28212875 -5.83728857
#  -5.80876726 -5.30010542 -4.04607018 -4.92875656 -4.22553314 -4.46640046
#  -4.28229211 -3.23180921]
